# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 1 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your Emory ID below

# %%
# Write your answer here
print("2484906")
# Out:
# 2484906

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should your run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"
#
# **By printing the message, you acknowledge that you will abide by Emory's code of conduct.**

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct.")
# Out:
# I will abide by Emory's code of conduct.

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pytplot", and "pandas"

# %%
# Write your answer here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:darkblue"> Part I: Visualizing Random Variables </span>

# %% [markdown]
# <font size = "5">
#
# (a) Create two random variables ...
#
#
# - Call them "vec_x" and "vec_z"
# - Generate "vec_x" from a uniform distribution with (low = 10, high = 20, size = 1000)
# - Generate "vec_z" from a chi-square distribution with (df = 1, size = 1000)
# - Plot a histogram of each variable
#     - Label the axes and title
#     - Each graph should have a different title
#
# To get full points, plot the histograms on a grid (See Lecture 6)

# %%
# Write your own code:
vec_x = np.random.uniform(low = 10, high = 20, size = 1000)
vec_z = np.random.chisquare(df=1, size=1000)
plt.hist(vec_x)
plt.xlabel("random vector variable x")
plt.ylabel("frequency of x")
plt.title("frequency of x, a uniform random variable with a low of 10 and high of 20.")
plt.grid()
plt.show()
plt.hist(vec_z)
plt.xlabel("random vector variable x")
plt.ylabel("frequency of x")
plt.title("frequency of z, a chi-square random variable with one degree of freedom and high of 20.")
plt.grid()
plt.show()

# %% [markdown]
# <font size = "5">
#
# (b) Create a new variable "vec_y" by the formula
#
# $ y = e^x + 2x + 5$
#
# - Use element-by-element vector operations (no loops)
# - Produce a scatter plot of "vec_y" against "vec_x"
# - Label the axes and the title
# - Change the color to "red", "green" or "purple" (you choose)
#
# Hint: You can use the numpy "exp()" function with vector arrays

# %%
# Write your own code:
def y(x):
    return np.exp(x) + 2*x + 5
vec_y = y(vec_x)
plt.scatter(vec_x, vec_y, color = 'purple')
plt.xlabel("random variable 'x'")
plt.ylabel("y(x)")
plt.title(f"Random variable x compared with $e^x + 2x + 5$")
plt.grid()

# %% [markdown]
# ## <span style="color:darkblue"> Part II: Operations over multiple datasets </span>

# %% [markdown]
# <font size = "5">
#
# (c) Creates two lists with ...
#
# - The names of the datasets
# - The years of the datasets (type manually based on the dataset names)
#
# To answer this question, you need to browse the Quiz folder
#
# You will find three datasets on the distribution of ages worldwide

# %%
# Write your own code
import os
elements = os.listdir('data_quiz')
years = [int(item[8:12]) for item in elements]
elements, years
# Out:
# (['wdi_ages2000.csv', 'wdi_ages2020.csv', 'wdi_ages1980.csv'],
#  [2000, 2020, 1980])

# %% [markdown]
# <font size = "5">
#
# (d) Create a loop that ...
#
#
# - Goes over the list of years
# - If the year $\ge$ 2000, print the message
#
# $\qquad$ "This dataset contains information on or after 2000.
#
# - If the year $<$ 2000, print the message
#
# $\qquad$ "This dataset contains information before 2000"

# %%
# Write your own code
for element, year in zip (elements,years):
    if year >= 2000:
        print(f"This dataset contains information on or after 2000.")
    else:
        print(f"This dataset contains information before 2000")
# Out:
# This dataset contains information on or after 2000.
# This dataset contains information on or after 2000.
# This dataset contains information before 2000

# %% [markdown]
# <font size = "5">
#
# (e) Your goal is to convert all the ".csv" data files to ".xlsx" (Excel) files
#
# <font size = "4">
#
# - **Before answering** this question do use your terminal (in Mac) or Anaconda prompt (in windows) to install the following package: ```conda install openpyxl```
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Create a new list called "list_newnames", with each element ending in ".xlsx" (including the subfolder "data_excel/")
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the ".csv" dataset and store it in an object called "dataset"
#     - Create a variable called "filename" from the "list_newnames", extracting the element "index"
#     - Store "dataset" as an excel file with name "filename".
#
#     $\qquad$ index = index + 1
#
# Note: Check that you did it correctly by trying to open your new excel files outside "VSCode"

# %%
# Write your own code:
# !conda install openpyxl
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: | ^C
# unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
#
# CondaError: KeyboardInterrupt

# %%
csv_quiz = ["data_quiz/" + element for element in elements]
list_newnames = ["data_excel/" + element[:-3] + "xlsx" for element in elements]
index = 0
for i in range(len(csv_quiz)):
    df = pd.read_csv(csv_quiz[i])
    df.to_excel(list_newnames[i])
    print(list_newnames[i])
# Out:
# data_excel/wdi_ages2000.xlsx
# data_excel/wdi_ages2020.xlsx
# data_excel/wdi_ages1980.xlsx

# %% [markdown]
# <font size = "5">
#
# (f) Your goal is to open each dataset, create a new variable, then plot
#
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the dataset and store it in an object called "dataset"
#     - Create two new variables as
#
#     $\qquad$ percent_ages0to14 = dataset["percent_ages0to14"] <br>
#     $\qquad$ percent_ages15to64 = dataset["percent_ages15to64"]
#
#     - Calculate the percent of the population between ages 0 and 64 by adding the two previous variables
#     - Plot a histogram and label the axes
#     - Use plt.show() to display the plot
#     - Write
#
#     $\qquad$ index = index + 1
#
#
# This should produce a histogram for each dataset

# %%
# Write your own code:
index = 0
for name in csv_quiz:
    dataset = pd.read_csv(name)
    percent_ages0to14 = dataset["percent_ages0to14"]
    print(percent_ages0to14)
    percent_ages15to64 = dataset['percent_ages15to64']
    percent_ages0to64 = percent_ages0to14 + percent_ages15to64
    plt.hist(percent_ages0to64, bins = 100)
    plt.grid()
    plt.xlabel("percent of age 0 to 64")
    plt.ylabel("frequency")
    plt.title("frequency map of year/country combinations with frequency of those ages 0 to 64")
    plt.show()
    index += 1
# Out:
# 0      49.718258
# 1      29.543870
# 2      33.837187
# 3      40.154046
# 4      15.277431
#          ...
# 265    30.220558
# 266          NaN
# 267          NaN
# 268          NaN
# 269          NaN
# Name: percent_ages0to14, Length: 270, dtype: float64
# 0      43.807912
# 1      16.471519
# 2      30.647083
# 3      28.198272
# 4      13.334620
#          ...
# 265    25.699053
# 266          NaN
# 267          NaN
# 268          NaN
# 269          NaN
# Name: percent_ages0to14, Length: 270, dtype: float64
# 0      45.972855
# 1      36.306595
# 2      46.408476
# 3      41.576075
# 4      23.732835
#          ...
# 265    35.387187
# 266          NaN
# 267          NaN
# 268          NaN
# 269          NaN
# Name: percent_ages0to14, Length: 270, dtype: float64
